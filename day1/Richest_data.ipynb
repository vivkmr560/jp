# %%
# %run "/Workspace/Users/vivkmr560@gmail.com/day1/includes"

# %%
df=spark.read.csv(f"{input_files}1000_richest_people_in_the_world.csv",header=True,inferSchema=True)

# %%
df_final=(df
        .withColumnRenamed("Net Worth (in billions)","net_worth_in_billions")
        .withColumn("ingestion_date",current_timestamp()))

# %%
df_final.display()

# %%
df_final.write.saveAsTable("dev.vivek.richest_people")

# %%
df=spark.read.table("dev.vivek.richest_people")
df.display()

# %%
df_final.write.mode("overwrite").saveAsTable("dev.vivek.richest_people")

# %%
# %sql
select * from dev.vivek.richest_people

# %%
df_final.write.mode("append").saveAsTable("dev.vivek.richest_people")
