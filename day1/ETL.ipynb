# %%
df=spark.read.option("header",True).csv("/Volumes/dev/naval/raw/sales.csv")
df.show()
df.display()

# %%
df.printSchema()

# %%
from pyspark.sql.functions import col,current_timestamp
df1=df.select("order_id",col("customer_id"),df.transaction_id).display()
df2=df.select(col("order_id").alias("orderID")).display()

# %%
df.withColumn("ingestion_date",current_timestamp()).display()
