# %%
# %sql
use catalog dev;

# %%
# %sql
create schema if not exists vivek;

# %%
# %sql
create table if not exists vivek.tbl1(id int, name string);
    
insert into vivek.tbl1 values(1,'vivek'),(2,'john'),(3,'mary');

# %%
# %sql
select * from vivek.tbl1;
