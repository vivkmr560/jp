# %%
# %sql
create schema if not exists dev.vivek_bronze;
create schema if not exists dev.vivek_silver;
create schema if not exists dev.vivek_gold;

# %%
# %python
input_path="/Volumes/dev/default/task"

# %%
# %python
from pyspark.sql.functions import *

# %%
# %python
def add_ingestion_date(df):
    df1=df.withColumn("ingestion_date",current_timestamp())
    return df1
