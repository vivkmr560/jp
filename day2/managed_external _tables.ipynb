# %%
# %sql
create table dev.vivek.external_demo_vivek (id int, name string) location 's3://jpmbspanlabs/external/vivek/external_1_vivek'

# %%
# %sql
insert into dev.vivek.external_demo_vivek values (1, 'Vivek'), (2, 'Jane')

# %%
# %sql
select * from delta.`s3://jpmbspanlabs/external/vivek/external_1_vivek`

# %%
df.write.option("path","s3://jpmbspanlabs/external/vivek/external_1_vivek").option("format","parquet").saveAsTable("vivek_tb")

# %%
# %sql
CREATE TABLE T(c1 INT) TBLPROPERTIES(
  'delta.columnMapping.mode' = 'name',
  'delta.enableIcebergCompatV2' = 'true',
  'delta.universalFormat.enabledFormats' = 'iceberg');
